# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavi64/VERZEO_Internship/blob/main/verzeo_major_project_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('data (1).csv.csv')
data
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0     2015       100198  409-8743  Female   36                     62
# 1     2015       100643  340-5930  Female   39                    149
# 2     2015       100756  372-3750  Female   65                    126
# 3     2015       101595  331-4902  Female   24                    131
# 4     2015       101653  351-8398  Female   40                    191
# ...    ...          ...       ...     ...  ...                    ...
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080     NaN   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
data.head()
# Out:
#    year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0  2015       100198  409-8743  Female   36                     62
# 1  2015       100643  340-5930  Female   39                    149
# 2  2015       100756  372-3750  Female   65                    126
# 3  2015       101595  331-4902  Female   24                    131
# 4  2015       101653  351-8398  Female   40                    191
#
#   multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 0           no              no               148.35                12.2
# 1           no              no               294.45                 7.7
# 2           no              no                87.30                11.9
# 3           no             yes               321.30                 9.5
# 4           no              no               243.00                10.9
#
#    maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# 0               16.81                     82               1
# ...

# %%
data.tail()
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080     NaN   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 1995           no             yes               182.25                11.3
# 1996           no              no               273.45                 9.3
# 1997           no              no               128.85                15.6
# 1998           no              no               178.05                10.4
# 1999           no              no               326.70                10.3
#
#       maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# ...

# %%
data[1000:1010]
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 1000  2015       568065  410-5192  Female   29                     30
# 1001  2015       568068  360-8919  Female   39                    224
# 1002  2015       568662  367-6005    Male   33                     90
# 1003  2015       568684  331-9149  Female   49                    139
# 1004  2015       568793  331-3698  Female   25                    174
# 1005  2015       568912  400-3197    Male   26                     16
# 1006  2015       571702  332-5949  Female   39                     46
# 1007  2015       571817  394-3048    Male   53                    126
# 1008  2015       571867  361-9845    Male   31                     92
# 1009  2015       571980  374-1684    Male   39                     22
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 1000           no              no               206.40                 5.8
# ...

# %% [markdown]
# DATA PREPARATION

# %%
data.shape
# Out:
# (2000, 16)

# %%
data.describe()
# Out:
#          year    customer_id         age  no_of_days_subscribed  \
# count  2000.0    2000.000000  2000.00000            2000.000000
# mean   2015.0  554887.157500    38.69050              99.750000
# std       0.0  261033.690318    10.20641              39.755386
# min    2015.0  100198.000000    18.00000               1.000000
# 25%    2015.0  328634.750000    32.00000              73.000000
# 50%    2015.0  567957.500000    37.00000              99.000000
# 75%    2015.0  773280.250000    44.00000             127.000000
# max    2015.0  999961.000000    82.00000             243.000000
#
#        weekly_mins_watched  minimum_daily_mins  maximum_daily_mins  \
# count          2000.000000         2000.000000         2000.000000
# mean            270.178425           10.198700           30.620780
# std              80.551627            2.785519            9.129165
# min               0.000000            0.000000            0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    2000 non-null   int64
#  1   customer_id             2000 non-null   int64
#  2   phone_no                2000 non-null   object
#  3   gender                  1976 non-null   object
#  4   age                     2000 non-null   int64
#  5   no_of_days_subscribed   2000 non-null   int64
#  6   multi_screen            2000 non-null   object
#  7   mail_subscribed         2000 non-null   object
#  8   weekly_mins_watched     2000 non-null   float64
#  9   minimum_daily_mins      2000 non-null   float64
#  10  maximum_daily_mins      2000 non-null   float64
#  11  weekly_max_night_mins   2000 non-null   int64
#  12  videos_watched          2000 non-null   int64
#  13  maximum_days_inactive   1972 non-null   float64
# ...

# %%
data.columns
# Out:
# Index(['year', 'customer_id', 'phone_no', 'gender', 'age',
#        'no_of_days_subscribed', 'multi_screen', 'mail_subscribed',
#        'weekly_mins_watched', 'minimum_daily_mins', 'maximum_daily_mins',
#        'weekly_max_night_mins', 'videos_watched', 'maximum_days_inactive',
#        'customer_support_calls', 'churn'],
#       dtype='object')

# %%
data['gender'].unique()
# Out:
# array(['Female', nan, 'Male'], dtype=object)

# %%
data['gender'].value_counts()
# Out:
# Male      1053
# Female     923
# Name: gender, dtype: int64

# %%
data['gender'].fillna(value='Male',inplace=True)
data
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0     2015       100198  409-8743  Female   36                     62
# 1     2015       100643  340-5930  Female   39                    149
# 2     2015       100756  372-3750  Female   65                    126
# 3     2015       101595  331-4902  Female   24                    131
# 4     2015       101653  351-8398  Female   40                    191
# ...    ...          ...       ...     ...  ...                    ...
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080    Male   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    2000 non-null   int64
#  1   customer_id             2000 non-null   int64
#  2   phone_no                2000 non-null   object
#  3   gender                  2000 non-null   object
#  4   age                     2000 non-null   int64
#  5   no_of_days_subscribed   2000 non-null   int64
#  6   multi_screen            2000 non-null   object
#  7   mail_subscribed         2000 non-null   object
#  8   weekly_mins_watched     2000 non-null   float64
#  9   minimum_daily_mins      2000 non-null   float64
#  10  maximum_daily_mins      2000 non-null   float64
#  11  weekly_max_night_mins   2000 non-null   int64
#  12  videos_watched          2000 non-null   int64
#  13  maximum_days_inactive   1972 non-null   float64
# ...

# %%
data = data.drop(["phone_no"],axis=1)
data
# Out:
#       year  customer_id  gender  age  no_of_days_subscribed multi_screen  \
# 0     2015       100198  Female   36                     62           no
# 1     2015       100643  Female   39                    149           no
# 2     2015       100756  Female   65                    126           no
# 3     2015       101595  Female   24                    131           no
# 4     2015       101653  Female   40                    191           no
# ...    ...          ...     ...  ...                    ...          ...
# 1995  2015       997132  Female   54                     75           no
# 1996  2015       998086    Male   45                    127           no
# 1997  2015       998474    Male   53                     94           no
# 1998  2015       998934    Male   40                     94           no
# 1999  2015       999961    Male   37                     73           no
#
#      mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
data['maximum_days_inactive'].fillna(value=0,inplace=True)
data
# Out:
#       year  customer_id  gender  age  no_of_days_subscribed multi_screen  \
# 0     2015       100198  Female   36                     62           no
# 1     2015       100643  Female   39                    149           no
# 2     2015       100756  Female   65                    126           no
# 3     2015       101595  Female   24                    131           no
# 4     2015       101653  Female   40                    191           no
# ...    ...          ...     ...  ...                    ...          ...
# 1995  2015       997132  Female   54                     75           no
# 1996  2015       998086    Male   45                    127           no
# 1997  2015       998474    Male   53                     94           no
# 1998  2015       998934    Male   40                     94           no
# 1999  2015       999961    Male   37                     73           no
#
#      mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
data['churn'].fillna(value=0,inplace=True)
data
# Out:
#       year  customer_id  gender  age  no_of_days_subscribed multi_screen  \
# 0     2015       100198  Female   36                     62           no
# 1     2015       100643  Female   39                    149           no
# 2     2015       100756  Female   65                    126           no
# 3     2015       101595  Female   24                    131           no
# 4     2015       101653  Female   40                    191           no
# ...    ...          ...     ...  ...                    ...          ...
# 1995  2015       997132  Female   54                     75           no
# 1996  2015       998086    Male   45                    127           no
# 1997  2015       998474    Male   53                     94           no
# 1998  2015       998934    Male   40                     94           no
# 1999  2015       999961    Male   37                     73           no
#
#      mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    2000 non-null   int64
#  1   customer_id             2000 non-null   int64
#  2   gender                  2000 non-null   object
#  3   age                     2000 non-null   int64
#  4   no_of_days_subscribed   2000 non-null   int64
#  5   multi_screen            2000 non-null   object
#  6   mail_subscribed         2000 non-null   object
#  7   weekly_mins_watched     2000 non-null   float64
#  8   minimum_daily_mins      2000 non-null   float64
#  9   maximum_daily_mins      2000 non-null   float64
#  10  weekly_max_night_mins   2000 non-null   int64
#  11  videos_watched          2000 non-null   int64
#  12  maximum_days_inactive   2000 non-null   float64
#  13  customer_support_calls  2000 non-null   int64
# ...

# %%
data.isnull().sum()
# Out:
# year                      0
# customer_id               0
# gender                    0
# age                       0
# no_of_days_subscribed     0
# multi_screen              0
# mail_subscribed           0
# weekly_mins_watched       0
# minimum_daily_mins        0
# maximum_daily_mins        0
# weekly_max_night_mins     0
# videos_watched            0
# maximum_days_inactive     0
# customer_support_calls    0
# churn                     0
# dtype: int64

# %%
sns.countplot(data['churn'])
# Out:
# <AxesSubplot:xlabel='churn', ylabel='count'>

# %% [markdown]
# TRAIN AND TEST DATA

# %%
from sklearn.model_selection import train_test_split

# %%
x , y = train_test_split(data,test_size=0.2)

# %%
X_train =  x[['year', 'customer_id', 'age',
       'no_of_days_subscribed', 
       'weekly_mins_watched', 'minimum_daily_mins', 'maximum_daily_mins',
       'weekly_max_night_mins', 'videos_watched', 'maximum_days_inactive',
       'customer_support_calls']]
Y_train = x['churn']

Y_train = x['churn']
X_test = y[['year', 'customer_id',  'age',
       'no_of_days_subscribed',  
       'weekly_mins_watched', 'minimum_daily_mins', 'maximum_daily_mins',
       'weekly_max_night_mins', 'videos_watched', 'maximum_days_inactive',
       'customer_support_calls']]
Y_test = y['churn']

# %%
from sklearn.linear_model import LogisticRegression
pk = LogisticRegression()

# %%
pk.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
y_pred = pk.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(Y_test,y_pred)
# Out:
# array([[357,   0],
#        [ 43,   0]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# ACCURACY

# %%
accuracy_score(Y_test,y_pred)
# Out:
# 0.8925

# %% [markdown]
# Here i got 89% of accuracy that tells about that how many customers takes the scbscription for next year
